# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('betas.csv')
df.head()
# Out:
#     alpha      beta
# 0      10  0.505000
# 1     100  0.484000
# 2    1000  0.438001
# 3   10000  0.357003
# 4  100000  0.295005

# %%
plt.plot(df['alpha'], df['beta'])
plt.xscale('log')
plt.show()
