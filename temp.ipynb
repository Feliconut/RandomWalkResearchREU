# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('betas.csv')
df.head()
# Out:
#       alpha      beta
# 0  0.000000  0.500195
# 1  0.040080  0.485358
# 2  0.080160  0.452058
# 3  0.120240  0.450643
# 4  0.160321  0.441405

# %%
plt.plot(df['alpha'], df['beta'])
plt.show()
