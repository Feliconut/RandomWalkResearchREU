# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('betas.csv')
df.head()
# Out:
#       alpha      beta
# 0  1.000000  0.310295
# 1  1.090909  0.312426
# 2  1.181818  0.303657
# 3  1.272727  0.291699
# 4  1.363636  0.296143

# %%
plt.plot(df['alpha'], df['beta'])
plt.show()

# %%
import scipy
x = np.linspace(0, 1, 1000) * 2 * np.pi
plt.plot(x, scipy.stats.wrapcauchy.cdf(x, 0.5))
plt.show()
