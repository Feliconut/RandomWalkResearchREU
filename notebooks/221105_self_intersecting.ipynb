# %%
import walk
from experiment import MultipleExperiment

# %%
def wf(weight):
    return weight ** (1/2)

test = MultipleExperiment(walk.SelfInteractingRandomWalk, n_trials=1, length=100, weight_function=wf)
test.run()
test.plot(0)

# %%
def wf2(weight):
    return weight ** 2

test2 = MultipleExperiment(walk.SelfInteractingRandomWalk, n_trials=1, length=100, weight_function=wf2)
test2.run()
test2.plot(0)

# %%
def wf3(weight):
    return weight + 5

test3 = MultipleExperiment(walk.SelfInteractingRandomWalk, n_trials=1, length=100, weight_function=wf3)
test3.run()
test3.plot(0)
